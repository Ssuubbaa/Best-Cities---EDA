# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sweetviz as sv

# %%
df = pd.read_csv('Best_Cities_for_Startups.csv')
df
# Out:
#      position change in position from 2020               city  \
# 0           1                            0  San Francisco Bay
# 1           2                            0           New York
# 2           3                            3            Beijing
# 3           4                            1   Los Angeles Area
# 4           5                            2             London
# ..        ...                          ...                ...
# 995       996                           26        Ouagadougou
# 996       997                          new            Baghdad
# 997       998                           13            Mbabane
# 998       999                          new            Conakry
# 999      1000                          new              Sanaa
#
#              country  total score  quatity score  quality score  \
# 0      United States      328.966          29.14         296.02
# 1      United States      110.777          11.43          95.55
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# position                          0
# change in position from 2020      0
# city                              0
# country                           0
# total score                       0
# quatity score                     0
# quality score                     0
# business score                    0
# sign of change in position      202
# dtype: int64

# %%
df.columns
# Out:
# Index(['position', 'change in position from 2020', 'city', 'country',
#        'total score', 'quatity score', 'quality score', 'business score',
#        'sign of change in position'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.shape[0]
# Out:
# 1000

# %%
df.dropna(axis = 0, how = 'all', inplace = True)

# %%
df.shape[0]
# Out:
# 1000

# %%
df.describe()
# Out:
#           position  total score  quatity score  quality score  business score
# count  1000.000000  1000.000000    1000.000000    1000.000000     1000.000000
# mean    500.500000     2.433854       0.343920       1.223350        0.867160
# std     288.819436    12.055121       1.347019      10.487355        1.148477
# min       1.000000     0.037000       0.010000       0.010000        0.000000
# 25%     250.750000     0.190750       0.020000       0.030000        0.140000
# 50%     500.500000     0.367000       0.040000       0.040000        0.270000
# 75%     750.250000     1.362500       0.180000       0.140000        1.030000
# max    1000.000000   328.966000      29.140000     296.020000        3.800000

# %%
df[df['change in position from 2020']== '0']
# Out:
#      position change in position from 2020               city         country  \
# 0           1                            0  San Francisco Bay   United States
# 1           2                            0           New York   United States
# 8           9                            0             Moscow          Russia
# 37         38                            0             Munich         Germany
# 65         66                            0            Tallinn         Estonia
# 76         77                            0             Bogota        Colombia
# 232       233                            0              Lille          France
#
#      total score  quatity score  quality score  business score  \
# 0        328.966          29.14         296.02            3.80
# 1        110.777          11.43          95.55            3.80
# 8         25.401           7.37          15.64            2.39
# 37        11.769           1.80           6.47            3.49
# ...

# %%
df[df['change in position from 2020']== '0'].count()  # totally 7 cities didn't change their ranking position
# Out:
# position                        7
# change in position from 2020    7
# city                            7
# country                         7
# total score                     7
# quatity score                   7
# quality score                   7
# business score                  7
# sign of change in position      0
# dtype: int64

# %%
df.corr()
# Out:
#                 position  total score  quatity score  quality score  \
# position        1.000000    -0.279582      -0.358950      -0.186913
# total score    -0.279582     1.000000       0.921991       0.991778
# quatity score  -0.358950     0.921991       1.000000       0.881724
# quality score  -0.186913     0.991778       0.881724       1.000000
# business score -0.806506     0.358643       0.453313       0.244499
#
#                 business score
# position             -0.806506
# total score           0.358643
# quatity score         0.453313
# quality score         0.244499
# business score        1.000000

# %%
sns.boxplot(df['total score'])
# Out:
# C:\Users\Subathra Rao\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total score'>

# %%
sns.boxplot(df['quatity score'])
# Out:
# C:\Users\Subathra Rao\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='quatity score'>

# %%
sns.boxplot(df['quality score'])
# Out:
# C:\Users\Subathra Rao\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='quality score'>

# %%
sns.boxplot(df['business score'])
# Out:
# C:\Users\Subathra Rao\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='business score'>

# %%
data_profiling = sv.analyze(df)
data_profiling.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
 df[df['total score'] == df['total score'].max()] # San Francisco Bay ranked '1' and didn't change their rank position
# Out:
#    position change in position from 2020               city         country  \
# 0         1                            0  San Francisco Bay   United States
#
#    total score  quatity score  quality score  business score  \
# 0      328.966          29.14         296.02             3.8
#
#   sign of change in position
# 0                        NaN

# %%
df
# Out:
#      position change in position from 2020               city  \
# 0           1                            0  San Francisco Bay
# 1           2                            0           New York
# 2           3                            3            Beijing
# 3           4                            1   Los Angeles Area
# 4           5                            2             London
# ..        ...                          ...                ...
# 995       996                           26        Ouagadougou
# 996       997                          new            Baghdad
# 997       998                           13            Mbabane
# 998       999                          new            Conakry
# 999      1000                          new              Sanaa
#
#              country  total score  quatity score  quality score  \
# 0      United States      328.966          29.14         296.02
# 1      United States      110.777          11.43          95.55
# ...

# %%
df['change in position from 2020'].value_counts()
# Out:
# new    195
# 1       19
# 5       16
# 6       16
# 11      15
#       ...
# 260      1
# 472      1
# 132      1
# 428      1
# 194      1
# Name: change in position from 2020, Length: 235, dtype: int64

# %%
df[df['change in position from 2020']== 'new']  #195 cities as new entry in ranking
# Out:
#      position change in position from 2020          city          country  \
# 161       162                          new         Busan      South Korea
# 203       204                          new  Sankt Gallen      Switzerland
# 207       208                          new       Reading   United Kingdom
# 239       240                          new       Fukuoka            Japan
# 284       285                          new       Hsinchu           Taiwan
# ..        ...                          ...           ...              ...
# 992       993                          new    Chattogram       Bangladesh
# 994       995                          new       Cotonou            Benin
# 996       997                          new       Baghdad             Iraq
# 998       999                          new       Conakry           Guinea
# 999      1000                          new         Sanaa            Yemen
#
#      total score  quatity score  quality score  business score  \
# ...

# %%
df['city'].value_counts()  #city name same but country different
# Out:
# Victoria     2
# Worcester    2
# Athens       2
# Windsor      2
# Vitoria      2
#             ..
# Essen        1
# Brasilia     1
# Aachen       1
# Tunis        1
# Sanaa        1
# Name: city, Length: 983, dtype: int64

# %%
df.isnull().sum()
# Out:
# position                          0
# change in position from 2020      0
# city                              0
# country                           0
# total score                       0
# quatity score                     0
# quality score                     0
# business score                    0
# sign of change in position      202
# dtype: int64

# %%
total = df.groupby('city')['total score'].sum().sort_values(ascending=False).reset_index()

# %%
total
# Out:
#                   city  total score
# 0    San Francisco Bay      328.966
# 1             New York      110.777
# 2              Beijing       66.049
# 3     Los Angeles Area       58.441
# 4               London       57.279
# ..                 ...          ...
# 978        Ouagadougou        0.060
# 979            Baghdad        0.058
# 980            Mbabane        0.057
# 981            Conakry        0.047
# 982              Sanaa        0.037
#
# [983 rows x 2 columns]

# %%
business = df.groupby('city')['business score'].sum().sort_values(ascending=False).reset_index()

# %%
business
# Out:
#                  city  business score
# 0          Manchester            4.14
# 1              London            3.99
# 2              Oxford            3.85
# 3        Indianapolis            3.80
# 4           Las Vegas            3.80
# ..                ...             ...
# 978             Sanaa            0.01
# 979  Saint Peter Port            0.00
# 980      Saint Helier            0.00
# 981         Gibraltar            0.00
# 982           Douglas            0.00
#
# [983 rows x 2 columns]

# %%
quantity = df.groupby('city')['quatity score'].sum().sort_values(ascending=False).reset_index()

# %%
quantity
# Out:
#                   city  quatity score
# 0    San Francisco Bay          29.14
# 1               London          15.82
# 2             New York          11.43
# 3     Los Angeles Area          11.23
# 4               Moscow           7.37
# ..                 ...            ...
# 978             Kassel           0.01
# 979            Conakry           0.01
# 980             Colima           0.01
# 981             Sursee           0.01
# 982             Multan           0.01
#
# [983 rows x 2 columns]

# %%
quality_score = df.groupby('city')['quality score'].sum().sort_values(ascending=False).reset_index()

# %%
quality_score
# Out:
#                   city  quality score
# 0    San Francisco Bay         296.02
# 1             New York          95.55
# 2              Beijing          58.61
# 3     Los Angeles Area          43.41
# 4          Boston Area          40.53
# ..                 ...            ...
# 978           Duisburg           0.02
# 979             Zwolle           0.02
# 980     Kaohsiung City           0.01
# 981      Taichung City           0.01
# 982        Tainan City           0.01
#
# [983 rows x 2 columns]

# %%
sns.set(rc={"figure.figsize" :(15,5)})
ax = sns.barplot(data=total,x='city',y='total score')
ax.tick_params(axis='x',rotation=90)

# %%
sns.set(rc={"figure.figsize" :(15,10)})
ax = sns.barplot(data=business,x='city',y='business score')
ax.tick_params(axis='x',rotation=90)

# %%
sns.set(rc={"figure.figsize" :(15,10)})
ax = sns.barplot(data=quantity,x='city',y='quatity score')
ax.tick_params(axis='x',rotation=90)

# %%
sns.set(rc={"figure.figsize" :(15,10)})
ax = sns.scatterplot(data=quality_score,x='city',y='quality score')
ax.tick_params(axis='x',rotation=90)

# %%
tc = df.groupby(['city'])['total score'].sum().sort_values(ascending=False).nsmallest(10).to_frame()
tc = tc.reset_index()

# %%
sns.set(rc={"figure.figsize" :(15,10)})
ax = sns.barplot(data=tc,x='city',y='total score')
ax.tick_params(axis='x',rotation=90)

# %%
df= df.head(10)[['city','quatity score', 'quality score',
                              'business score']].set_index('city')
fig, ax=plt.subplots(figsize=(15,6))
df.plot(kind='bar', stacked=True, color=['wheat','slateblue','magenta'], ax=ax)
ax.set_title('Top 10 Countries for Start-up (3 Metrics)', fontsize=15);

# %% [markdown]
# INFERENCE:
#     1. Totally 7 countries didn't change their ranking position
#     2. 195 cities as new entry in ranking
#     3. San Francisco Bay ranked '1' and didn't change their rank position.
